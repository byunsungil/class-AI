# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 1
b = 2
c = 3
d = 4

# %%
a+b, a-b, a+c
# Out:
# (3, -1, 4)

# %%
print(a+b)
# Out:
# 3

# %%
print(a+b,a-b,a+c)
# Out:
# 3 -1 4

# %%
print(a+b)
# Out:
# 3

# %%
print(d/b)
# Out:
# 2.0

# %%
print(d%c)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
input()
# Out:
# 10
# '10'

# %%
type(a)
# Out:
# int

# %%
a = input(a)
# Out:
# 110

# %%
type(a)

# %%
a = int(input())
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a = float(input())
# Out:
# 10

# %%
type(a)
# Out:
# float

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("hi \n")
print("\t hi")
print("hi\\")
print("hi\'in'")
print("\"hi")
print("abcde\r")
print("di\f")
print("\a")
print("aeee\b")
print("\000")
# Out:
# hi
#
# 	 hi
# hi\
# hi'in'
# "hi
# abcde
# di
#
# aeee
# de

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 10
b = 20

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a != b
# Out:
# True

# %%
print(bool(1))
# Out:
# True

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(3))
# Out:
# True

# %%
print(bool(""))
# Out:
# False

# %%
print(())
# Out:
# ()

# %%
print(bool("안녕"))
# Out:
# True

# %%
not a == b
# Out:
# True

# %%
10 == a and b == 20
# Out:
# True

# %%
10 == a or b == 25
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("+"*10)
# Out:
# ++++++++++

# %%
"Life is too short, You need Python"
# Out:
# 'Life is too short, You need Python'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = "안녕하세요 지금은 인공지능 수업 시간입니다."

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A[0:4] # 0~3
# Out:
# '안녕하세'

# %%
A[-1]
# Out:
# '.'

# %%
A[-5:] # 맨뒤는 0으로 할 수 없으므로 -1 부터
# Out:
# '간입니다.'

# %%
A[5:]
# Out:
# ' 지금은 인공지능 수업 시간입니다.'

# %%
print("안녕하세요\n반갑습니다")
# Out:
# 안녕하세요
# 반갑습니다

# %%
print("이번시험의 성적으로 %d점을 맞았습니다"%30)
# Out:
# 이번시험의 성적으로 30점을 맞았습니다

# %%
print(("이번시험에서 수학은 {}점 영어는 {}점 국어는 {}점 맞았습니다.").format(100,60,60))
# Out:
# 이번시험에서 수학은 100점 영어는 60점 국어는 60점 맞았습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "i am a "
b = "boy"

# %%
a+b
# Out:
# 'i am a boy'

# %%
a = "i am a {}"
b = "boy"

# %%
a.format(b)
# Out:
# 'i am a boy'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("{}, {}".format(10, 190))
"i am a {}".format(10)
# Out:
# 10, 190
# 'i am a 10'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("{:.2f},{:.3f}".format(3.1415, 3.1415))
# Out:
# 3.14,3.142

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
url = "https://www.youtube.com/"

# %%
str = url.replace("https://","")

# %%
str
# Out:
# 'www.youtube.com/'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "독고영재, 50"
b = "김철수, 30"

# %%
a[:a.index(",")]
# Out:
# '독고영재'

# %%
b[:b.index(",")]
# Out:
# '김철수'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "독고영재, 50"
b = "김철수, 30"

# %%
ab = [a,b]

# %%
ab
# Out:
# ['독고영재, 50', '김철수, 30']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A[0:4]
# Out:
# '안녕하세'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
B = [10,20,30,40,50,60,70,80,90]

# %%
B[0:4]
# Out:
# [10, 20, 30, 40]

# %%
B[0]
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ab[0]
# Out:
# '독고영재, 50'

# %%
ab[0][0:4]
# Out:
# '독고영재'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = ["독고영재, 50", "김철수, 30"]

# %%
a[0][:a[0].index(",")]
# Out:
# '독고영재'
